# %% [markdown]
# <a href="https://colab.research.google.com/github/ZHANJINGCHUN/LLIE_Project/blob/main/GSAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## initialize

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/LLIDProjects/GSAD')

# %% [markdown]
# ## install lpips

# %%
# !pip install lpips
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 45.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 92.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## install kmeans_pytorch

# %%
# !pip install kmeans_pytorch

# %% [markdown]
# ## test on paired dataset-LOL

# %%
# !python test.py --dataset ./config/lolv1.yml --config ./config/lolv1_test.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# Disabled distributed training.
# 24-03-18 05:16:19.436 - INFO:   name: lolv1_test
#   phase: test
#   gpu_ids: [0]
#   seed: 4088
#   path:[
#     log: experiments/lolv1_test_240318_051619/logs
#     tb_logger: experiments/lolv1_test_240318_051619/tb_logger
#     results: experiments/lolv1_test_240318_051619/results
#     checkpoint: experiments/lolv1_test_240318_051619/checkpoint
#     resume_state: ./checkpoints/lolv1_gen.pth
#     experiments_root: experiments/lolv1_test_240318_051619
#   ]
#   model:[
#     which_model_G: ddpm
#     finetune_norm: False
#     unet:[
#       in_channel: 6
#       out_channel: 3
#       inner_channel: 64
#       channel_multiplier: [1, 1, 2, 2, 4]
#       attn_res: [16]
#       res_blocks: 2
#       dropout: 0
#     ]
#     beta_schedule:[
#       train:[
#         schedule: linear
#         n_timestep: 500
#         linear_start: 0.0001
#         linear_end: 0.02
#       ]
#       val:[
#         schedule: linear
# ...

# %%
# !python test.py --dataset ./config/lolv2_real.yml --config ./config/lolv2_real_test.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# Disabled distributed training.
# 24-03-18 05:27:28.111 - INFO:   name: lolv2_test_real
#   phase: test
#   gpu_ids: [0]
#   seed: 4357
#   path:[
#     log: experiments/lolv2_test_real_240318_052728/logs
#     tb_logger: experiments/lolv2_test_real_240318_052728/tb_logger
#     results: experiments/lolv2_test_real_240318_052728/results
#     checkpoint: experiments/lolv2_test_real_240318_052728/checkpoint
#     resume_state: ./checkpoints/lolv2_real_gen.pth
#     experiments_root: experiments/lolv2_test_real_240318_052728
#   ]
#   model:[
#     which_model_G: ddpm
#     finetune_norm: False
#     unet:[
#       in_channel: 6
#       out_channel: 3
#       inner_channel: 64
#       channel_multiplier: [1, 1, 2, 2, 4]
#       attn_res: [16]
#       res_blocks: 2
#       dropout: 0
#     ]
#     beta_schedule:[
#       train:[
#         schedule: linear
#         n_timestep: 500
#         linear_start: 0.0001
#         linear_end: 0.02
#       ]
# ...

# %%
# !python test.py --dataset ./config/lolv2_syn.yml --config ./config/lolv2_syn_test.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# Disabled distributed training.
# 24-03-18 05:33:06.934 - INFO:   name: lolv2_test_syn
#   phase: test
#   gpu_ids: [0]
#   seed: 8477
#   path:[
#     log: experiments/lolv2_test_syn_240318_053306/logs
#     tb_logger: experiments/lolv2_test_syn_240318_053306/tb_logger
#     results: experiments/lolv2_test_syn_240318_053306/results
#     checkpoint: experiments/lolv2_test_syn_240318_053306/checkpoint
#     resume_state: ./checkpoints/lolv2_syn_gen.pth
#     experiments_root: experiments/lolv2_test_syn_240318_053306
#   ]
#   model:[
#     which_model_G: ddpm
#     finetune_norm: False
#     unet:[
#       in_channel: 6
#       out_channel: 3
#       inner_channel: 64
#       channel_multiplier: [1, 1, 2, 2, 4]
#       attn_res: [16]
#       res_blocks: 2
#       dropout: 0
#     ]
#     beta_schedule:[
#       train:[
#         schedule: linear
#         n_timestep: 500
#         linear_start: 0.0001
#         linear_end: 0.02
#       ]
#       val:[
# ...

# %%
# !bash train.sh
# Out:
# export CUDA_VISIBLE_DEVICES=0
# Disabled distributed training.
# 24-03-18 05:42:57.686 - INFO:   name: train_llie_diff_uncertainty
#   phase: train
#   gpu_ids: [0]
#   path:[
#     log: experiments/train_llie_diff_uncertainty_240318_054257/logs
#     tb_logger: experiments/train_llie_diff_uncertainty_240318_054257/tb_logger
#     results: experiments/train_llie_diff_uncertainty_240318_054257/results
#     checkpoint: experiments/train_llie_diff_uncertainty_240318_054257/checkpoint
#     resume_state: None
#     experiments_root: experiments/train_llie_diff_uncertainty_240318_054257
#   ]
#   model:[
#     which_model_G: ddpm
#     finetune_norm: False
#     unet:[
#       in_channel: 6
#       out_channel: 3
#       inner_channel: 64
#       channel_multiplier: [1, 1, 2, 2, 4]
#       attn_res: [16]
#       res_blocks: 2
#       dropout: 0
#     ]
#     beta_schedule:[
#       train:[
#         schedule: linear
#         n_timestep: 500
#         linear_start: 0.0001
# ...

# %% [markdown]
# ## Testing on Unpaired Dataset

# %%
# !python test_unpaired.py  --config config/test_unpaired.json --input /content/drive/MyDrive/DATASETS/LOLv1/eval15/low/

# %%
# !python test_unpaired.py  --config config/test_unpaired.json --input /content/drive/MyDrive/DATASETS/ExDark/People/
# Out:
# export CUDA_VISIBLE_DEVICES=0
# Disabled distributed training.
# 24-04-04 08:22:42.008 - INFO: Random seed: 4952
# ddpm
# ddpm
# 24-04-04 08:22:52.335 - INFO: GaussianDiffusion(
#   (denoise_fn): UNet(
#     (noise_level_mlp): Sequential(
#       (0): PositionalEncoding()
#       (1): Linear(in_features=64, out_features=256, bias=True)
#       (2): Swish()
#       (3): Linear(in_features=256, out_features=64, bias=True)
#     )
#     (downs): ModuleList(
#       (0): Conv2d(6, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1-2): 2 x ResnetBlocWithAttn(
#         (res_block): ResnetBlock(
#           (mlp): Sequential(
#             (0): Swish()
#             (1): Linear(in_features=64, out_features=64, bias=True)
#           )
#           (noise_func): FeatureWiseAffine(
#             (noise_func): Sequential(
#               (0): Linear(in_features=64, out_features=64, bias=True)
#             )
#           )
#           (block1): Block(
# ...

# %% [markdown]
# ## Test by Images By Zhan

# %%
# !python test_unpaired.py  --config config/test_unpaired.json --input /content/drive/MyDrive/DATASETS/CaptureByZhan/
# Out:
# python3: can't open file '/content/test_unpaired.py': [Errno 2] No such file or directory

# %% [markdown]
# ## try

# %%
# !python test.py --dataset ./config/lolv1.yml --config ./config/lolv1_test.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# Disabled distributed training.
# 24-04-06 08:44:09.959 - INFO:   name: lolv1_test
#   phase: test
#   gpu_ids: [0]
#   seed: 4088
#   path:[
#     log: experiments/lolv1_test_240406_084409/logs
#     tb_logger: experiments/lolv1_test_240406_084409/tb_logger
#     results: experiments/lolv1_test_240406_084409/results
#     checkpoint: experiments/lolv1_test_240406_084409/checkpoint
#     resume_state: ./checkpoints/lolv1_gen.pth
#     experiments_root: experiments/lolv1_test_240406_084409
#   ]
#   model:[
#     which_model_G: ddpm
#     finetune_norm: False
#     unet:[
#       in_channel: 6
#       out_channel: 3
#       inner_channel: 64
#       channel_multiplier: [1, 1, 2, 2, 4]
#       attn_res: [16]
#       res_blocks: 2
#       dropout: 0
#     ]
#     beta_schedule:[
#       train:[
#         schedule: linear
#         n_timestep: 500
#         linear_start: 0.0001
#         linear_end: 0.02
#       ]
#       val:[
#         schedule: linear
# ...
